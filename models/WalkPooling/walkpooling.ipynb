# %%
import numpy as np
import pandas as pd
import torch
# from logs import log
from tqdm.notebook import tqdm
# from tqdm import tqdm
import networkx as nx
import os
import torch.nn as nn
import torch_geometric.transforms as T
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GAE, VGAE, APPNP
from torch_geometric.data import InMemoryDataset, Data
from torch_geometric.loader import DataLoader
from torch_geometric.utils import from_networkx, negative_sampling, to_networkx
from sklearn.metrics import roc_auc_score, average_precision_score
from model import LinkPred

# %% [markdown]
# ### WalkPooling model version logs:
#     * ver1: WalkPooling first try.

# %%
"""Datasets:
    * id: edge id, 
    * from & to: 'from' node point to 'to' node, 
    * label: connect or not.
    * content: containing each node's attribute.

   Evaluate:
    * AUC: area under ROC curve
    * AP: average precision
"""
data_path = '../dataset1/'
store_file = 'WalkPool_ver1_submission'
# log_file = 'logs/'+store_file+'.log'
# logger = log(path=data_path, file=log_file)

df_train = pd.read_csv(data_path+'raw/train.csv').sort_values('from')
df_test = pd.read_csv(data_path+'raw/test.csv')
df_content = pd.read_csv(data_path+'raw/content.csv', delimiter='\t', header=None)
df_upload = pd.read_csv(data_path+'raw/upload.csv')

# %%
class Graph_dataset(InMemoryDataset):
    def __init__(self, root, transform=None, pre_transform=None):
        super(Graph_dataset, self).__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])
    
    @property
    def raw_file_names(self):
        return ['train.csv', 'content.csv']
    
    @property
    def processed_file_names(self):
        return ['train.pt']
    
    def download(self):
        pass

    def process(self):
        self.data = pd.read_csv(self.raw_paths[0]).sort_values('from')
        node_feats = pd.read_csv(self.raw_paths[1], delimiter='\t', header=None, index_col=0)
        
        # Get node features. [num_nodes, num_node_features]
        x = torch.tensor(node_feats.sort_index().values, dtype=torch.float)
        
        # Get positive data.(label = 1: link)
        pos_data = self.data[self.data['label'] == 1]
        # neg_data = self.data[self.data['label'] == 0]

        # Get edge index.
        graph = nx.from_pandas_edgelist(pos_data, 'from', 'to', edge_attr=None)

        pair1 = [i[0] for i in graph.edges()]
        pair2 = [i[1] for i in graph.edges()]
        pos_edge_index = torch.LongTensor([pair1+pair2,pair2+pair1])

        # Create Data object.
        proc_graph = Data(x=x,
                          edge_index=pos_edge_index,
                          y=None)
        print(proc_graph)

        data, slices = self.collate([proc_graph])
        torch.save((data, slices), self.processed_paths[0])

# %%
demo = Graph_dataset(data_path)
data = demo.data
data = T.NormalizeFeatures()(data)
train_data, val_data, test_data = T.RandomLinkSplit(num_val=0.05, 
                                                    num_test=0.1, 
                                                    split_labels=True, 
                                                    is_undirected=True, 
                                                    add_negative_train_samples=False
                                                    )(data)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# c:\ProgramData\Anaconda3\envs\pytorch\lib\site-packages\torch_geometric\data\in_memory_dataset.py:157: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)

# %%
class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(VariationalGCNEncoder, self).__init__()
        hidden_channels=64
        self.conv1 = GCNConv(in_channels, hidden_channels, cached=True)
        self.conv_mu = GCNConv(hidden_channels, out_channels, cached=True)
        self.conv_logstd = GCNConv(hidden_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)
    
def compute_scores(z,test_pos,test_neg):
    test = torch.cat((test_pos, test_neg),dim=1)
    labels = torch.zeros(test.size(1),1)
    labels[0:test_pos.size(1)] = 1
    row, col = test
    src = z[row]
    tgt = z[col]
    scores = torch.sigmoid(torch.sum(src * tgt,dim=1))
    auc = roc_auc_score(labels, scores)
    ap = average_precision_score(labels, scores)
    return auc,ap

def CalVGAE(edge_index, x, test_and_val, embedding_dim):
    print('___Calculating VGAE embbeding___')
    test_pos,test_neg,val_pos,val_neg=test_and_val
    out_channels = int(embedding_dim)
    num_features = x.size(1)
    model = VGAE(VariationalGCNEncoder(num_features, out_channels)).to(device)
    edge_index = edge_index.to(device)
    x = x.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
    num_nodes = torch.max(edge_index)
    best_val_auc=0
    for epoch in range(1, 500 + 1):
        model.train()
        optimizer.zero_grad()
        z = model.encode(x, edge_index)
        loss = model.recon_loss(z, edge_index)
        loss = loss + (1 / num_nodes) * model.kl_loss()
        loss.backward()
        optimizer.step()
        if epoch%10 == 0:
            model.eval()
            z = model.encode(x, edge_index)
            z = z.cpu().clone().detach()
            auc,_=compute_scores(z,val_pos,val_neg)
            if auc>best_val_auc:
                best_val_auc=auc
                record_z=z.clone().detach()
            print(f'Setp: {epoch:03d} /500, Loss : {loss.item():.4f}, Val_auc:{best_val_auc:.4f}')
            
    auc,ap=compute_scores(record_z,test_pos,test_neg)
    
    print(f'vgae prediction accuracy, AUC: {auc:.4f}, AP: {ap:.4f}')
    del model
    torch.cuda.empty_cache()
    return record_z, auc, ap

# %%
def set_init_attribute_representation(train_data, val_data, test_data):
    data_observed = Data(edge_index=train_data.edge_index)
    data_observed.num_nodes = train_data.num_nodes
    
    edge_index_observed = data_observed.edge_index
    
    x = train_data.x
    val_and_test = [test_data.pos_edge_label_index, test_data.neg_edge_label_index, val_data.pos_edge_label_index, val_data.neg_edge_label_index]
    num_nodes, _ = x.shape

    if (num_nodes-1) in edge_index_observed:
        # .clone().detach() info. https://blog.csdn.net/Answer3664/article/details/104417013
        edge_index_observed=edge_index_observed.clone().detach()
    else:
        edge_index_observed=torch.cat((edge_index_observed.clone().detach(),torch.tensor([[num_nodes-1],[num_nodes-1]])),dim=1)

    data_observed.x, auc, ap = CalVGAE(edge_index_observed, x, val_and_test, embedding_dim=32)
    feature_results = [auc, ap]

    return data_observed, feature_results

# %%
import scipy.sparse as ssp
from scipy.sparse.csgraph import shortest_path
# Drnl feature in the SEAL paper
def drnl_node_labeling(edge_index, src, dst, num_nodes):

    edge_weight = torch.ones(edge_index.size(1), dtype=int)
    adj = ssp.csr_matrix(
            (edge_weight, (edge_index[0], edge_index[1])), 
            shape=(num_nodes, num_nodes))
    # Double Radius Node Labeling (DRNL).
    src, dst = (dst, src) if src > dst else (src, dst)

    idx = list(range(src)) + list(range(src + 1, adj.shape[0]))
    adj_wo_src = adj[idx, :][:, idx]

    idx = list(range(dst)) + list(range(dst + 1, adj.shape[0]))
    adj_wo_dst = adj[idx, :][:, idx]

    dist2src = shortest_path(adj_wo_dst, directed=False, unweighted=True, indices=src)
    dist2src = np.insert(dist2src, dst, 0, axis=0)
    dist2src = torch.from_numpy(dist2src)

    dist2dst = shortest_path(adj_wo_src, directed=False, unweighted=True, indices=dst-1)
    dist2dst = np.insert(dist2dst, src, 0, axis=0)
    dist2dst = torch.from_numpy(dist2dst)

    dist = dist2src + dist2dst
    dist_over_2, dist_mod_2 = dist // 2, dist % 2

    z = 1 + torch.min(dist2src, dist2dst)
    z += dist_over_2 * (dist_over_2 + dist_mod_2 - 1)
    z[src] = 1.
    z[dst] = 1.
    z[torch.isnan(z)] = 0.
    return z.to(torch.int)

# %%
train_data.pos_edge_label_index
# Out:
# tensor([[ 374, 1048, 1537,  ..., 1601,  625,  387],
#         [2506, 2180, 2273,  ..., 2695, 1325, 2405]])

# %%
def k_hop_subgraph(node_idx, num_hops, edge_index, max_nodes_per_hop = None, num_nodes = None):
    row, col = edge_index
    node_mask = row.new_empty(num_nodes, dtype=torch.bool)
    edge_mask = row.new_empty(row.size(0), dtype=torch.bool)

    node_idx = node_idx.to(row.device)

    subsets = [node_idx]

    not_visited = row.new_empty(num_nodes, dtype=torch.bool)
    not_visited.fill_(True)

    for _ in range(num_hops):
        node_mask.fill_(False) # The source node mask in this hop.
        node_mask[subsets[-1]] = True# mark the sources
        not_visited[subsets[-1]] = False # mark visited nodes
        torch.index_select(node_mask, 0, row, out=edge_mask) # indices of all neighbors

        neighbors = col[edge_mask].unique() # remove repeats
        neighbor_mask = row.new_empty(num_nodes, dtype=torch.bool) # mask of all neighbor nodes
        edge_mask_hop = row.new_empty(row.size(0), dtype=torch.bool) # selected neighbor mask in this hop
        neighbor_mask.fill_(False)
        neighbor_mask[neighbors] = True
        neighbor_mask = torch.logical_and(neighbor_mask, not_visited) # all neighbors that are not visited
        ind = torch.where(neighbor_mask == True) # indicies of all the unvisited neighbors

        if ind[0].size(0) > max_nodes_per_hop:
            perm = torch.randperm(ind[0].size(0))
            ind = ind[0][perm]
            neighbor_mask[ind[max_nodes_per_hop:]] = False # randomly select max_nodes_per_hop nodes
            torch.index_select(neighbor_mask, 0, col, out = edge_mask_hop) # find the indicies of selected nodes
            edge_mask = torch.logical_and(edge_mask, edge_mask_hop) # change edge_mask
        subsets.append(col[edge_mask_hop])

    subset, inv = torch.cat(subsets).unique(return_inverse=True)
    inv = inv[:node_idx.numel()]

    node_mask.fill_(False)
    node_mask[subset] = True
    edge_mask = node_mask[row] & node_mask[col]

    edge_index = edge_index[:, edge_mask]

    node_idx = row.new_full((num_nodes, ), -1)
    node_idx[subset] = torch.arange(subset.size(0), device=row.device)
    edge_index = node_idx[edge_index]

    return subset, edge_index, inv, edge_mask

def minus_edge(data_observed, label, pos_edge, use_drnl):
    nodes, pos_edge_index, mapping, _ = k_hop_subgraph(node_idx=pos_edge, 
                                                       num_hops=2, 
                                                       edge_index=data_observed.edge_index,
                                                       max_nodes_per_hop=100, 
                                                       num_nodes=data_observed.num_nodes)
    x_sub = data_observed.x[nodes, :]

    # edge_mask marks the edge under pertubation, i.e., the candidate edge for LP
    edge_mask = torch.ones(pos_edge_index.size(1), dtype=torch.bool)
    ind = torch.where((pos_edge_index == mapping.view(-1, 1)).all(dim=0))
    edge_mask[ind[0]] = False
    ind = torch.where((pos_edge_index == mapping[[1, 0]].view(-1, 1)).all(dim=0))
    edge_mask[ind[0]] = False

    if use_drnl == True:
        num_nodes = torch.max(pos_edge_index)+1
        z = drnl_node_labeling(pos_edge_index[:, edge_mask], mapping[0], mapping[1], num_nodes)
        data = Data(edge_index = pos_edge_index, x = x_sub, z = z)
    else:
        data = Data(edge_index = pos_edge_index, x = x_sub, z = 0)
    data.edge_mask = edge_mask

    # label = 1 if the candidate link (p_edge) is positive and label=0 otherwis
    data.label = float(label)
    return data

def plus_edge(data_observed, label, pos_edge, use_drnl):
    nodes, edge_index_m, mapping, _ = k_hop_subgraph(node_idx=pos_edge, 
                                                     num_hops=2, 
                                                     edge_index=data_observed.edge_index,
                                                     max_nodes_per_hop=100, 
                                                     num_nodes=data_observed.num_nodes)
    x_sub = data_observed.x[nodes, :]
    pos_edge_index = edge_index_m
    pos_edge_index = torch.cat((pos_edge_index, mapping.view(-1, 1)), dim=1)
    pos_edge_index = torch.cat((pos_edge_index, mapping[[1, 0]].view(-1, 1)), dim=1)

    #edge_mask marks the edge under perturbation, i.e., the candidate edge for LP
    edge_mask = torch.ones(pos_edge_index.size(1),dtype=torch.bool)
    edge_mask[-1] = False
    edge_mask[-2] = False

    if use_drnl == True:
        num_nodes = torch.max(pos_edge_index)+1
        z = drnl_node_labeling(edge_index_m, mapping[0],mapping[1],num_nodes)
        data = Data(edge_index = pos_edge_index, x = x_sub, z = z)
    else:
        data = Data(edge_index = pos_edge_index, x = x_sub, z = 0)
    data.edge_mask = edge_mask

    #label = 1 if the candidate link (p_edge) is positive and label=0 otherwise
    data.label = float(label)

    return data

# %%
data_observed, feature_results = set_init_attribute_representation(train_data, val_data, test_data)

# sampling training negatives for every training epoch
neg_train_index = negative_sampling(edge_index=train_data.edge_index,
                                    num_nodes=train_data.num_nodes,
                                    num_neg_samples=train_data.pos_edge_label_index.size(1),
                                    method='sparse')

train_graphs = []
val_graphs = []
test_graphs = []

# run total edge.
for i in range(train_data.pos_edge_label_index.size(1)):
    train_graphs.append(minus_edge(data_observed, 1, train_data.pos_edge_label_index[:, i], False))
for i in range(neg_train_index.size(1)):
    train_graphs.append(plus_edge(data_observed, 0, neg_train_index[:, i], False))

for i in range(test_data.pos_edge_label_index.size(1)):
    test_graphs.append(plus_edge(data_observed, 1, test_data.pos_edge_label_index[:, i], False))
for i in range(test_data.neg_edge_label_index.size(1)):
    test_graphs.append(plus_edge(data_observed, 0, test_data.neg_edge_label_index[:, i], False))

for i in range(val_data.pos_edge_label_index.size(1)):
    val_graphs.append(plus_edge(data_observed, 1, val_data.pos_edge_label_index[:, i], False))
for i in range(val_data.neg_edge_label_index.size(1)):
    val_graphs.append(plus_edge(data_observed, 0, val_data.neg_edge_label_index[:, i], False))

print('Train_link:', str(len(train_graphs)),' Val_link:',str(len(val_graphs)),' Test_link:',str(len(test_graphs)))

train_loader = DataLoader(train_graphs,batch_size=4,shuffle=True)
val_loader = DataLoader(val_graphs,batch_size=4,shuffle=True)
test_loader = DataLoader(test_graphs,batch_size=4,shuffle=False)
# Out:
# ___Calculating VGAE embbeding___
# Setp: 010 /500, Loss : 3.4462, Val_auc:0.7082
# Setp: 020 /500, Loss : 1.9746, Val_auc:0.7082
# Setp: 030 /500, Loss : 1.4562, Val_auc:0.7082
# Setp: 040 /500, Loss : 1.3756, Val_auc:0.7082
# Setp: 050 /500, Loss : 1.3599, Val_auc:0.7141
# Setp: 060 /500, Loss : 1.3364, Val_auc:0.7141
# Setp: 070 /500, Loss : 1.2979, Val_auc:0.7201
# Setp: 080 /500, Loss : 1.2056, Val_auc:0.7229
# Setp: 090 /500, Loss : 1.1766, Val_auc:0.7229
# Setp: 100 /500, Loss : 1.1499, Val_auc:0.7231
# Setp: 110 /500, Loss : 1.1323, Val_auc:0.7256
# Setp: 120 /500, Loss : 1.1180, Val_auc:0.7257
# Setp: 130 /500, Loss : 1.1164, Val_auc:0.7403
# Setp: 140 /500, Loss : 1.0988, Val_auc:0.7542
# Setp: 150 /500, Loss : 1.0699, Val_auc:0.7692
# Setp: 160 /500, Loss : 1.0363, Val_auc:0.8115
# Setp: 170 /500, Loss : 1.0171, Val_auc:0.8269
# Setp: 180 /500, Loss : 0.9992, Val_auc:0.8288
# Setp: 190 /500, Loss : 1.0040, Val_auc:0.8300
# Setp: 200 /500, Loss : 1.0052, Val_auc:0.8367
# Setp: 210 /500, Loss : 0.9956, Val_auc:0.8381
# Setp: 220 /500, Loss : 0.9914, Val_auc:0.8381
# Setp: 230 /500, Loss : 0.9757, Val_auc:0.8485
# Setp: 240 /500, Loss : 0.9591, Val_auc:0.8552
# Setp: 250 /500, Loss : 0.9569, Val_auc:0.8563
# Setp: 260 /500, Loss : 0.9551, Val_auc:0.8637
# Setp: 270 /500, Loss : 0.9589, Val_auc:0.8684
# Setp: 280 /500, Loss : 0.9449, Val_auc:0.8713
# Setp: 290 /500, Loss : 0.9262, Val_auc:0.8794
# Setp: 300 /500, Loss : 0.9312, Val_auc:0.8851
# Setp: 310 /500, Loss : 0.9262, Val_auc:0.8851
# Setp: 320 /500, Loss : 0.9320, Val_auc:0.8851
# Setp: 330 /500, Loss : 0.9195, Val_auc:0.8851
# Setp: 340 /500, Loss : 0.9195, Val_auc:0.8851
# Setp: 350 /500, Loss : 0.9144, Val_auc:0.8864
# Setp: 360 /500, Loss : 0.9128, Val_auc:0.8864
# Setp: 370 /500, Loss : 0.9118, Val_auc:0.8864
# Setp: 380 /500, Loss : 0.9027, Val_auc:0.8864
# Setp: 390 /500, Loss : 0.9074, Val_auc:0.8864
# Setp: 400 /500, Loss : 0.9027, Val_auc:0.8864
# Setp: 410 /500, Loss : 0.9011, Val_auc:0.8864
# Setp: 420 /500, Loss : 0.8953, Val_auc:0.8864
# Setp: 430 /500, Loss : 0.8901, Val_auc:0.8864
# Setp: 440 /500, Loss : 0.8959, Val_auc:0.8864
# Setp: 450 /500, Loss : 0.8830, Val_auc:0.8864
# Setp: 460 /500, Loss : 0.8868, Val_auc:0.8864
# Setp: 470 /500, Loss : 0.8812, Val_auc:0.8864
# Setp: 480 /500, Loss : 0.8914, Val_auc:0.8864
# Setp: 490 /500, Loss : 0.8859, Val_auc:0.8864
# Setp: 500 /500, Loss : 0.8681, Val_auc:0.8864
# vgae prediction accuracy, AUC: 0.8543, AP: 0.8640
# Train_link: 7204  Val_link: 422  Test_link: 846

# %%
for i in test_loader:
    print(i)
# Out:
# DataBatch(x=[9437, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9437], ptr=[5])
# DataBatch(x=[9436, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9436], ptr=[5])
# DataBatch(x=[9436, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9436], ptr=[5])
# DataBatch(x=[9436, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9436], ptr=[5])
# DataBatch(x=[9437, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9437], ptr=[5])
# DataBatch(x=[9436, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9436], ptr=[5])
# DataBatch(x=[9436, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9436], ptr=[5])
# DataBatch(x=[9437, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9437], ptr=[5])
# DataBatch(x=[9437, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9437], ptr=[5])
# DataBatch(x=[9440, 32], edge_index=[2, 28256], z=[4], edge_mask=[28256], label=[4], batch=[9440], ptr=[5])
# DataBatch(x=[9443, 32], edge_index=[2, 28258], z=[4], edge_mask=[28258], label=[4], batch=[9443], ptr=[5])
# DataBatch(x=[9447, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9447], ptr=[5])
# DataBatch(x=[9444, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9444], ptr=[5])
# DataBatch(x=[9445, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9445], ptr=[5])
# DataBatch(x=[9445, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9445], ptr=[5])
# DataBatch(x=[9445, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9445], ptr=[5])
# DataBatch(x=[9445, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9445], ptr=[5])
# DataBatch(x=[9445, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9445], ptr=[5])
# DataBatch(x=[9444, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9444], ptr=[5])
# DataBatch(x=[9444, 32], edge_index=[2, 28264], z=[4], edge_mask=[28264], label=[4], batch=[9444], ptr=[5])
# DataBatch(x=[2527, 32], edge_index=[2, 6988], z=[4], edge_mask=[6988], label=[4], batch=[2527], ptr=[5])
# DataBatch(x=[2935, 32], edge_index=[2, 8300], z=[4], edge_mask=[8300], label=[4], batch=[2935], ptr=[5])
# DataBatch(x=[5716, 32], edge_index=[2, 17080], z=[4], edge_mask=[17080], label=[4], batch=[5716], ptr=[5])
# DataBatch(x=[4797, 32], edge_index=[2, 14154], z=[4], edge_mask=[14154], label=[4], batch=[4797], ptr=[5])
# DataBatch(x=[4770, 32], edge_index=[2, 13832], z=[4], edge_mask=[13832], label=[4], batch=[4770], ptr=[5])
# DataBatch(x=[2343, 32], edge_index=[2, 6432], z=[4], edge_mask=[6432], label=[4], batch=[2343], ptr=[5])
# DataBatch(x=[808, 32], edge_index=[2, 1240], z=[4], edge_mask=[1240], label=[4], batch=[808], ptr=[5])
# DataBatch(x=[1660, 32], edge_index=[2, 4304], z=[4], edge_mask=[4304], label=[4], batch=[1660], ptr=[5])
# DataBatch(x=[1085, 32], edge_index=[2, 2158], z=[4], edge_mask=[2158], label=[4], batch=[1085], ptr=[5])
# DataBatch(x=[1253, 32], edge_index=[2, 2646], z=[4], edge_mask=[2646], label=[4], batch=[1253], ptr=[5])
# DataBatch(x=[2144, 32], edge_index=[2, 6048], z=[4], edge_mask=[6048], label=[4], batch=[2144], ptr=[5])
# DataBatch(x=[2466, 32], edge_index=[2, 6816], z=[4], edge_mask=[6816], label=[4], batch=[2466], ptr=[5])
# DataBatch(x=[1973, 32], edge_index=[2, 5126], z=[4], edge_mask=[5126], label=[4], batch=[1973], ptr=[5])
# DataBatch(x=[1749, 32], edge_index=[2, 4548], z=[4], edge_mask=[4548], label=[4], batch=[1749], ptr=[5])
# DataBatch(x=[1182, 32], edge_index=[2, 2198], z=[4], edge_mask=[2198], label=[4], batch=[1182], ptr=[5])
# DataBatch(x=[981, 32], edge_index=[2, 1940], z=[4], edge_mask=[1940], label=[4], batch=[981], ptr=[5])
# DataBatch(x=[808, 32], edge_index=[2, 1246], z=[4], edge_mask=[1246], label=[4], batch=[808], ptr=[5])
# DataBatch(x=[2147, 32], edge_index=[2, 5952], z=[4], edge_mask=[5952], label=[4], batch=[2147], ptr=[5])
# DataBatch(x=[1828, 32], edge_index=[2, 4624], z=[4], edge_mask=[4624], label=[4], batch=[1828], ptr=[5])
# DataBatch(x=[2517, 32], edge_index=[2, 7152], z=[4], edge_mask=[7152], label=[4], batch=[2517], ptr=[5])
# DataBatch(x=[7188, 32], edge_index=[2, 22894], z=[4], edge_mask=[22894], label=[4], batch=[7188], ptr=[5])
# DataBatch(x=[8198, 32], edge_index=[2, 25708], z=[4], edge_mask=[25708], label=[4], batch=[8198], ptr=[5])
# DataBatch(x=[8605, 32], edge_index=[2, 26812], z=[4], edge_mask=[26812], label=[4], batch=[8605], ptr=[5])
# DataBatch(x=[8632, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8632], ptr=[5])
# DataBatch(x=[8625, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8625], ptr=[5])
# DataBatch(x=[8626, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8626], ptr=[5])
# DataBatch(x=[8625, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8625], ptr=[5])
# DataBatch(x=[8624, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8624], ptr=[5])
# DataBatch(x=[8625, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8625], ptr=[5])
# DataBatch(x=[8626, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8626], ptr=[5])
# DataBatch(x=[8624, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8624], ptr=[5])
# DataBatch(x=[8626, 32], edge_index=[2, 26880], z=[4], edge_mask=[26880], label=[4], batch=[8626], ptr=[5])
# DataBatch(x=[8643, 32], edge_index=[2, 26908], z=[4], edge_mask=[26908], label=[4], batch=[8643], ptr=[5])
# DataBatch(x=[8633, 32], edge_index=[2, 26888], z=[4], edge_mask=[26888], label=[4], batch=[8633], ptr=[5])
# DataBatch(x=[6686, 32], edge_index=[2, 20796], z=[4], edge_mask=[20796], label=[4], batch=[6686], ptr=[5])
# DataBatch(x=[3067, 32], edge_index=[2, 9176], z=[4], edge_mask=[9176], label=[4], batch=[3067], ptr=[5])
# DataBatch(x=[2477, 32], edge_index=[2, 7338], z=[4], edge_mask=[7338], label=[4], batch=[2477], ptr=[5])
# DataBatch(x=[2422, 32], edge_index=[2, 6960], z=[4], edge_mask=[6960], label=[4], batch=[2422], ptr=[5])
# DataBatch(x=[1428, 32], edge_index=[2, 3978], z=[4], edge_mask=[3978], label=[4], batch=[1428], ptr=[5])
# DataBatch(x=[4564, 32], edge_index=[2, 14324], z=[4], edge_mask=[14324], label=[4], batch=[4564], ptr=[5])
# DataBatch(x=[5104, 32], edge_index=[2, 15764], z=[4], edge_mask=[15764], label=[4], batch=[5104], ptr=[5])
# DataBatch(x=[2258, 32], edge_index=[2, 6100], z=[4], edge_mask=[6100], label=[4], batch=[2258], ptr=[5])
# DataBatch(x=[2151, 32], edge_index=[2, 5548], z=[4], edge_mask=[5548], label=[4], batch=[2151], ptr=[5])
# DataBatch(x=[1564, 32], edge_index=[2, 3706], z=[4], edge_mask=[3706], label=[4], batch=[1564], ptr=[5])
# DataBatch(x=[3175, 32], edge_index=[2, 9220], z=[4], edge_mask=[9220], label=[4], batch=[3175], ptr=[5])
# DataBatch(x=[1859, 32], edge_index=[2, 4110], z=[4], edge_mask=[4110], label=[4], batch=[1859], ptr=[5])
# DataBatch(x=[1860, 32], edge_index=[2, 4766], z=[4], edge_mask=[4766], label=[4], batch=[1860], ptr=[5])
# DataBatch(x=[1277, 32], edge_index=[2, 2886], z=[4], edge_mask=[2886], label=[4], batch=[1277], ptr=[5])
# DataBatch(x=[4841, 32], edge_index=[2, 14934], z=[4], edge_mask=[14934], label=[4], batch=[4841], ptr=[5])
# DataBatch(x=[2224, 32], edge_index=[2, 5874], z=[4], edge_mask=[5874], label=[4], batch=[2224], ptr=[5])
# DataBatch(x=[1167, 32], edge_index=[2, 2468], z=[4], edge_mask=[2468], label=[4], batch=[1167], ptr=[5])
# DataBatch(x=[1095, 32], edge_index=[2, 2156], z=[4], edge_mask=[2156], label=[4], batch=[1095], ptr=[5])
# DataBatch(x=[1575, 32], edge_index=[2, 4040], z=[4], edge_mask=[4040], label=[4], batch=[1575], ptr=[5])
# DataBatch(x=[2833, 32], edge_index=[2, 8662], z=[4], edge_mask=[8662], label=[4], batch=[2833], ptr=[5])
# DataBatch(x=[1510, 32], edge_index=[2, 2914], z=[4], edge_mask=[2914], label=[4], batch=[1510], ptr=[5])
# DataBatch(x=[2369, 32], edge_index=[2, 6254], z=[4], edge_mask=[6254], label=[4], batch=[2369], ptr=[5])
# DataBatch(x=[1657, 32], edge_index=[2, 4202], z=[4], edge_mask=[4202], label=[4], batch=[1657], ptr=[5])
# DataBatch(x=[1363, 32], edge_index=[2, 2954], z=[4], edge_mask=[2954], label=[4], batch=[1363], ptr=[5])
# DataBatch(x=[4761, 32], edge_index=[2, 14690], z=[4], edge_mask=[14690], label=[4], batch=[4761], ptr=[5])
# DataBatch(x=[8485, 32], edge_index=[2, 26516], z=[4], edge_mask=[26516], label=[4], batch=[8485], ptr=[5])
# DataBatch(x=[8708, 32], edge_index=[2, 27076], z=[4], edge_mask=[27076], label=[4], batch=[8708], ptr=[5])
# DataBatch(x=[8720, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8720], ptr=[5])
# DataBatch(x=[8720, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8720], ptr=[5])
# DataBatch(x=[8723, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8723], ptr=[5])
# DataBatch(x=[8720, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8720], ptr=[5])
# DataBatch(x=[8720, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8720], ptr=[5])
# DataBatch(x=[8724, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8724], ptr=[5])
# DataBatch(x=[8721, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8721], ptr=[5])
# DataBatch(x=[8722, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8722], ptr=[5])
# DataBatch(x=[8722, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8722], ptr=[5])
# DataBatch(x=[8720, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8720], ptr=[5])
# DataBatch(x=[8721, 32], edge_index=[2, 27120], z=[4], edge_mask=[27120], label=[4], batch=[8721], ptr=[5])
# DataBatch(x=[1058, 32], edge_index=[2, 2854], z=[4], edge_mask=[2854], label=[4], batch=[1058], ptr=[5])
# DataBatch(x=[1302, 32], edge_index=[2, 3108], z=[4], edge_mask=[3108], label=[4], batch=[1302], ptr=[5])
# DataBatch(x=[910, 32], edge_index=[2, 1642], z=[4], edge_mask=[1642], label=[4], batch=[910], ptr=[5])
# DataBatch(x=[1681, 32], edge_index=[2, 4554], z=[4], edge_mask=[4554], label=[4], batch=[1681], ptr=[5])
# DataBatch(x=[2723, 32], edge_index=[2, 7964], z=[4], edge_mask=[7964], label=[4], batch=[2723], ptr=[5])
# DataBatch(x=[808, 32], edge_index=[2, 1778], z=[4], edge_mask=[1778], label=[4], batch=[808], ptr=[5])
# DataBatch(x=[808, 32], edge_index=[2, 1478], z=[4], edge_mask=[1478], label=[4], batch=[808], ptr=[5])
# DataBatch(x=[909, 32], edge_index=[2, 1800], z=[4], edge_mask=[1800], label=[4], batch=[909], ptr=[5])
# DataBatch(x=[2349, 32], edge_index=[2, 6502], z=[4], edge_mask=[6502], label=[4], batch=[2349], ptr=[5])
# DataBatch(x=[1157, 32], edge_index=[2, 2130], z=[4], edge_mask=[2130], label=[4], batch=[1157], ptr=[5])
# DataBatch(x=[908, 32], edge_index=[2, 1452], z=[4], edge_mask=[1452], label=[4], batch=[908], ptr=[5])
# DataBatch(x=[1085, 32], edge_index=[2, 1982], z=[4], edge_mask=[1982], label=[4], batch=[1085], ptr=[5])
# DataBatch(x=[989, 32], edge_index=[2, 1830], z=[4], edge_mask=[1830], label=[4], batch=[989], ptr=[5])
# DataBatch(x=[926, 32], edge_index=[2, 2088], z=[4], edge_mask=[2088], label=[4], batch=[926], ptr=[5])
# DataBatch(x=[3213, 32], edge_index=[2, 7888], z=[4], edge_mask=[7888], label=[4], batch=[3213], ptr=[5])
# DataBatch(x=[1313, 32], edge_index=[2, 2588], z=[4], edge_mask=[2588], label=[4], batch=[1313], ptr=[5])
# DataBatch(x=[1522, 32], edge_index=[2, 3654], z=[4], edge_mask=[3654], label=[4], batch=[1522], ptr=[5])
# DataBatch(x=[1081, 32], edge_index=[2, 2318], z=[4], edge_mask=[2318], label=[4], batch=[1081], ptr=[5])
# DataBatch(x=[2235, 32], edge_index=[2, 6266], z=[4], edge_mask=[6266], label=[4], batch=[2235], ptr=[5])
# DataBatch(x=[3036, 32], edge_index=[2, 8974], z=[4], edge_mask=[8974], label=[4], batch=[3036], ptr=[5])
# DataBatch(x=[1306, 32], edge_index=[2, 2646], z=[4], edge_mask=[2646], label=[4], batch=[1306], ptr=[5])
# DataBatch(x=[881, 32], edge_index=[2, 1486], z=[4], edge_mask=[1486], label=[4], batch=[881], ptr=[5])
# DataBatch(x=[1611, 32], edge_index=[2, 4074], z=[4], edge_mask=[4074], label=[4], batch=[1611], ptr=[5])
# DataBatch(x=[3759, 32], edge_index=[2, 9846], z=[4], edge_mask=[9846], label=[4], batch=[3759], ptr=[5])
# DataBatch(x=[1034, 32], edge_index=[2, 1620], z=[4], edge_mask=[1620], label=[4], batch=[1034], ptr=[5])
# DataBatch(x=[908, 32], edge_index=[2, 1646], z=[4], edge_mask=[1646], label=[4], batch=[908], ptr=[5])
# DataBatch(x=[995, 32], edge_index=[2, 1906], z=[4], edge_mask=[1906], label=[4], batch=[995], ptr=[5])
# DataBatch(x=[1096, 32], edge_index=[2, 2158], z=[4], edge_mask=[2158], label=[4], batch=[1096], ptr=[5])
# DataBatch(x=[1172, 32], edge_index=[2, 2792], z=[4], edge_mask=[2792], label=[4], batch=[1172], ptr=[5])
# DataBatch(x=[3038, 32], edge_index=[2, 9392], z=[4], edge_mask=[9392], label=[4], batch=[3038], ptr=[5])
# DataBatch(x=[6202, 32], edge_index=[2, 19690], z=[4], edge_mask=[19690], label=[4], batch=[6202], ptr=[5])
# DataBatch(x=[7994, 32], edge_index=[2, 25112], z=[4], edge_mask=[25112], label=[4], batch=[7994], ptr=[5])
# DataBatch(x=[8589, 32], edge_index=[2, 26738], z=[4], edge_mask=[26738], label=[4], batch=[8589], ptr=[5])
# DataBatch(x=[8627, 32], edge_index=[2, 26824], z=[4], edge_mask=[26824], label=[4], batch=[8627], ptr=[5])
# DataBatch(x=[8644, 32], edge_index=[2, 26878], z=[4], edge_mask=[26878], label=[4], batch=[8644], ptr=[5])
# DataBatch(x=[8663, 32], edge_index=[2, 26944], z=[4], edge_mask=[26944], label=[4], batch=[8663], ptr=[5])
# DataBatch(x=[8672, 32], edge_index=[2, 26964], z=[4], edge_mask=[26964], label=[4], batch=[8672], ptr=[5])
# DataBatch(x=[8678, 32], edge_index=[2, 26968], z=[4], edge_mask=[26968], label=[4], batch=[8678], ptr=[5])
# DataBatch(x=[8678, 32], edge_index=[2, 26976], z=[4], edge_mask=[26976], label=[4], batch=[8678], ptr=[5])
# DataBatch(x=[8676, 32], edge_index=[2, 26976], z=[4], edge_mask=[26976], label=[4], batch=[8676], ptr=[5])
# DataBatch(x=[8679, 32], edge_index=[2, 26976], z=[4], edge_mask=[26976], label=[4], batch=[8679], ptr=[5])
# DataBatch(x=[8678, 32], edge_index=[2, 26976], z=[4], edge_mask=[26976], label=[4], batch=[8678], ptr=[5])
# DataBatch(x=[8681, 32], edge_index=[2, 26976], z=[4], edge_mask=[26976], label=[4], batch=[8681], ptr=[5])
# DataBatch(x=[8681, 32], edge_index=[2, 26976], z=[4], edge_mask=[26976], label=[4], batch=[8681], ptr=[5])
# DataBatch(x=[8697, 32], edge_index=[2, 26976], z=[4], edge_mask=[26976], label=[4], batch=[8697], ptr=[5])
# DataBatch(x=[8725, 32], edge_index=[2, 27004], z=[4], edge_mask=[27004], label=[4], batch=[8725], ptr=[5])
# DataBatch(x=[8757, 32], edge_index=[2, 27054], z=[4], edge_mask=[27054], label=[4], batch=[8757], ptr=[5])
# DataBatch(x=[8798, 32], edge_index=[2, 27138], z=[4], edge_mask=[27138], label=[4], batch=[8798], ptr=[5])
# DataBatch(x=[8829, 32], edge_index=[2, 27226], z=[4], edge_mask=[27226], label=[4], batch=[8829], ptr=[5])
# DataBatch(x=[8854, 32], edge_index=[2, 27304], z=[4], edge_mask=[27304], label=[4], batch=[8854], ptr=[5])
# DataBatch(x=[8858, 32], edge_index=[2, 27306], z=[4], edge_mask=[27306], label=[4], batch=[8858], ptr=[5])
# DataBatch(x=[8864, 32], edge_index=[2, 27314], z=[4], edge_mask=[27314], label=[4], batch=[8864], ptr=[5])
# DataBatch(x=[8867, 32], edge_index=[2, 27318], z=[4], edge_mask=[27318], label=[4], batch=[8867], ptr=[5])
# DataBatch(x=[8878, 32], edge_index=[2, 27328], z=[4], edge_mask=[27328], label=[4], batch=[8878], ptr=[5])
# DataBatch(x=[8881, 32], edge_index=[2, 27332], z=[4], edge_mask=[27332], label=[4], batch=[8881], ptr=[5])
# DataBatch(x=[8882, 32], edge_index=[2, 27336], z=[4], edge_mask=[27336], label=[4], batch=[8882], ptr=[5])
# DataBatch(x=[8883, 32], edge_index=[2, 27336], z=[4], edge_mask=[27336], label=[4], batch=[8883], ptr=[5])
# DataBatch(x=[8881, 32], edge_index=[2, 27336], z=[4], edge_mask=[27336], label=[4], batch=[8881], ptr=[5])
# DataBatch(x=[8892, 32], edge_index=[2, 27348], z=[4], edge_mask=[27348], label=[4], batch=[8892], ptr=[5])
# DataBatch(x=[8913, 32], edge_index=[2, 27396], z=[4], edge_mask=[27396], label=[4], batch=[8913], ptr=[5])
# DataBatch(x=[8926, 32], edge_index=[2, 27428], z=[4], edge_mask=[27428], label=[4], batch=[8926], ptr=[5])
# DataBatch(x=[8929, 32], edge_index=[2, 27432], z=[4], edge_mask=[27432], label=[4], batch=[8929], ptr=[5])
# DataBatch(x=[8939, 32], edge_index=[2, 27438], z=[4], edge_mask=[27438], label=[4], batch=[8939], ptr=[5])
# DataBatch(x=[8954, 32], edge_index=[2, 27456], z=[4], edge_mask=[27456], label=[4], batch=[8954], ptr=[5])
# DataBatch(x=[8961, 32], edge_index=[2, 27468], z=[4], edge_mask=[27468], label=[4], batch=[8961], ptr=[5])
# DataBatch(x=[8965, 32], edge_index=[2, 27474], z=[4], edge_mask=[27474], label=[4], batch=[8965], ptr=[5])
# DataBatch(x=[8971, 32], edge_index=[2, 27480], z=[4], edge_mask=[27480], label=[4], batch=[8971], ptr=[5])
# DataBatch(x=[8985, 32], edge_index=[2, 27512], z=[4], edge_mask=[27512], label=[4], batch=[8985], ptr=[5])
# DataBatch(x=[8987, 32], edge_index=[2, 27512], z=[4], edge_mask=[27512], label=[4], batch=[8987], ptr=[5])
# DataBatch(x=[8990, 32], edge_index=[2, 27520], z=[4], edge_mask=[27520], label=[4], batch=[8990], ptr=[5])
# DataBatch(x=[8996, 32], edge_index=[2, 27520], z=[4], edge_mask=[27520], label=[4], batch=[8996], ptr=[5])
# DataBatch(x=[9009, 32], edge_index=[2, 27536], z=[4], edge_mask=[27536], label=[4], batch=[9009], ptr=[5])
# DataBatch(x=[9015, 32], edge_index=[2, 27540], z=[4], edge_mask=[27540], label=[4], batch=[9015], ptr=[5])
# DataBatch(x=[9024, 32], edge_index=[2, 27552], z=[4], edge_mask=[27552], label=[4], batch=[9024], ptr=[5])
# DataBatch(x=[9025, 32], edge_index=[2, 27552], z=[4], edge_mask=[27552], label=[4], batch=[9025], ptr=[5])
# DataBatch(x=[9035, 32], edge_index=[2, 27566], z=[4], edge_mask=[27566], label=[4], batch=[9035], ptr=[5])
# DataBatch(x=[9038, 32], edge_index=[2, 27568], z=[4], edge_mask=[27568], label=[4], batch=[9038], ptr=[5])
# DataBatch(x=[9036, 32], edge_index=[2, 27568], z=[4], edge_mask=[27568], label=[4], batch=[9036], ptr=[5])
# DataBatch(x=[9051, 32], edge_index=[2, 27576], z=[4], edge_mask=[27576], label=[4], batch=[9051], ptr=[5])
# DataBatch(x=[9055, 32], edge_index=[2, 27586], z=[4], edge_mask=[27586], label=[4], batch=[9055], ptr=[5])
# DataBatch(x=[9056, 32], edge_index=[2, 27584], z=[4], edge_mask=[27584], label=[4], batch=[9056], ptr=[5])
# DataBatch(x=[9061, 32], edge_index=[2, 27592], z=[4], edge_mask=[27592], label=[4], batch=[9061], ptr=[5])
# DataBatch(x=[9062, 32], edge_index=[2, 27594], z=[4], edge_mask=[27594], label=[4], batch=[9062], ptr=[5])
# DataBatch(x=[9060, 32], edge_index=[2, 27592], z=[4], edge_mask=[27592], label=[4], batch=[9060], ptr=[5])
# DataBatch(x=[9064, 32], edge_index=[2, 27592], z=[4], edge_mask=[27592], label=[4], batch=[9064], ptr=[5])
# DataBatch(x=[9078, 32], edge_index=[2, 27608], z=[4], edge_mask=[27608], label=[4], batch=[9078], ptr=[5])
# DataBatch(x=[9083, 32], edge_index=[2, 27624], z=[4], edge_mask=[27624], label=[4], batch=[9083], ptr=[5])
# DataBatch(x=[9088, 32], edge_index=[2, 27624], z=[4], edge_mask=[27624], label=[4], batch=[9088], ptr=[5])
# DataBatch(x=[9090, 32], edge_index=[2, 27628], z=[4], edge_mask=[27628], label=[4], batch=[9090], ptr=[5])
# DataBatch(x=[9094, 32], edge_index=[2, 27640], z=[4], edge_mask=[27640], label=[4], batch=[9094], ptr=[5])
# DataBatch(x=[9103, 32], edge_index=[2, 27644], z=[4], edge_mask=[27644], label=[4], batch=[9103], ptr=[5])
# DataBatch(x=[9105, 32], edge_index=[2, 27648], z=[4], edge_mask=[27648], label=[4], batch=[9105], ptr=[5])
# DataBatch(x=[9111, 32], edge_index=[2, 27656], z=[4], edge_mask=[27656], label=[4], batch=[9111], ptr=[5])
# DataBatch(x=[9114, 32], edge_index=[2, 27658], z=[4], edge_mask=[27658], label=[4], batch=[9114], ptr=[5])
# DataBatch(x=[9114, 32], edge_index=[2, 27660], z=[4], edge_mask=[27660], label=[4], batch=[9114], ptr=[5])
# DataBatch(x=[9118, 32], edge_index=[2, 27664], z=[4], edge_mask=[27664], label=[4], batch=[9118], ptr=[5])
# DataBatch(x=[9122, 32], edge_index=[2, 27666], z=[4], edge_mask=[27666], label=[4], batch=[9122], ptr=[5])
# DataBatch(x=[9124, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9124], ptr=[5])
# DataBatch(x=[9128, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9128], ptr=[5])
# DataBatch(x=[9129, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9129], ptr=[5])
# DataBatch(x=[9130, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9130], ptr=[5])
# DataBatch(x=[9133, 32], edge_index=[2, 27676], z=[4], edge_mask=[27676], label=[4], batch=[9133], ptr=[5])
# DataBatch(x=[9130, 32], edge_index=[2, 27674], z=[4], edge_mask=[27674], label=[4], batch=[9130], ptr=[5])
# DataBatch(x=[9133, 32], edge_index=[2, 27680], z=[4], edge_mask=[27680], label=[4], batch=[9133], ptr=[5])
# DataBatch(x=[9127, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9127], ptr=[5])
# DataBatch(x=[9124, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9124], ptr=[5])
# DataBatch(x=[9127, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9127], ptr=[5])
# DataBatch(x=[9126, 32], edge_index=[2, 27672], z=[4], edge_mask=[27672], label=[4], batch=[9126], ptr=[5])
# DataBatch(x=[9129, 32], edge_index=[2, 27674], z=[4], edge_mask=[27674], label=[4], batch=[9129], ptr=[5])
# DataBatch(x=[9137, 32], edge_index=[2, 27696], z=[4], edge_mask=[27696], label=[4], batch=[9137], ptr=[5])
# DataBatch(x=[9136, 32], edge_index=[2, 27696], z=[4], edge_mask=[27696], label=[4], batch=[9136], ptr=[5])
# DataBatch(x=[9139, 32], edge_index=[2, 27696], z=[4], edge_mask=[27696], label=[4], batch=[9139], ptr=[5])
# DataBatch(x=[9141, 32], edge_index=[2, 27696], z=[4], edge_mask=[27696], label=[4], batch=[9141], ptr=[5])
# DataBatch(x=[9143, 32], edge_index=[2, 27700], z=[4], edge_mask=[27700], label=[4], batch=[9143], ptr=[5])
# DataBatch(x=[9144, 32], edge_index=[2, 27704], z=[4], edge_mask=[27704], label=[4], batch=[9144], ptr=[5])
# DataBatch(x=[9146, 32], edge_index=[2, 27704], z=[4], edge_mask=[27704], label=[4], batch=[9146], ptr=[5])
# DataBatch(x=[9145, 32], edge_index=[2, 27704], z=[4], edge_mask=[27704], label=[4], batch=[9145], ptr=[5])
# DataBatch(x=[9145, 32], edge_index=[2, 27704], z=[4], edge_mask=[27704], label=[4], batch=[9145], ptr=[5])
# DataBatch(x=[9146, 32], edge_index=[2, 27704], z=[4], edge_mask=[27704], label=[4], batch=[9146], ptr=[5])
# DataBatch(x=[4578, 32], edge_index=[2, 13854], z=[2], edge_mask=[13854], label=[2], batch=[4578], ptr=[3])

# %%
walk_len = 6
heads = 2
hidden_channels=32
lr=0.00005
weight_decay=0

torch.cuda.empty_cache()

num_features = next(iter(train_loader)).x.size(1)

z_max = 0
torch.cuda.empty_cache()
print("Dimention of features after concatenation:",num_features)
model = LinkPred(in_channels = num_features, hidden_channels = hidden_channels,\
    heads = heads, walk_len = walk_len, drnl = False,z_max = z_max, MSE= False).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay=weight_decay)
criterion = torch.nn.BCEWithLogitsLoss()
# Out:
# Dimention of features after concatenation: 32

# %%
def train(loader,epoch):
    model.train()
    loss_epoch=0
    for data in tqdm(loader,desc="train"):  # Iterate in batches over the training dataset.        
        data = data.to(device)
        label= data.label
        out = model(data.x, data.edge_index, data.edge_mask, data.batch, data.z)
        torch.cuda.empty_cache()
        loss = criterion(out.view(-1), label)  
        optimizer.zero_grad()
        loss.backward()  
        optimizer.step()
        loss_epoch=loss_epoch+loss.item()
    return loss_epoch/len(loader)

def test(loader,data_type='test'):
    model.eval()
    scores = torch.tensor([])
    labels = torch.tensor([])
    loss_total=0
    with torch.no_grad():
        #for data in tqdm(loader,position=0,leave=True):  # Iterate in batches over the training/test dataset.
        for data in tqdm(loader,desc='test:'+data_type):  # Iterate in batches over the training/test dataset.
            data = data.to(device)
            out = model(data.x, data.edge_index, data.edge_mask, data.batch, data.z)
            loss = criterion(out.view(-1), data.label)
            out = out.cpu().clone().detach()
            scores = torch.cat((scores,out),dim = 0)
            labels = torch.cat((labels,data.label.view(-1,1).cpu().clone().detach()),dim = 0)
        scores = scores.cpu().clone().detach().numpy()
        labels = labels.cpu().clone().detach().numpy()
        loss_total=loss_total+loss.item()
        return roc_auc_score(labels, scores), average_precision_score(labels, scores),loss_total

# %%
Best_Val_fromloss=1e10
Final_Test_AUC_fromloss=0
Final_Test_AP_fromloss=0

Best_Val_fromAUC=0
Final_Test_AUC_fromAUC=0
Final_Test_AP_fromAUC=0

for epoch in range(0, 50):
    loss_epoch = train(train_loader,epoch)
    val_auc, val_ap, val_loss = test(val_loader,data_type='val')
    test_auc,test_ap,_ = test(test_loader,data_type='test')
    if val_loss < Best_Val_fromloss:
        Best_Val_fromloss = val_loss
        Final_Test_AUC_fromloss = test_auc
        Final_Test_AP_fromloss = test_ap

    if val_auc > Best_Val_fromAUC:
        Best_Val_fromAUC = val_auc
        Final_Test_AUC_fromAUC = test_auc
        Final_Test_AP_fromAUC = test_ap
    print(f'Epoch: {epoch:03d}, Loss : {loss_epoch:.4f},\
     Val Loss : {val_loss:.4f}, Val AUC: {val_auc:.4f},\
      Test AUC: {test_auc:.4f}, Picked AUC:{Final_Test_AUC_fromAUC:.4f}')

print(f'From loss: Final Test AUC: {Final_Test_AUC_fromloss:.4f}, Final Test AP: {Final_Test_AP_fromloss:.4f}')
print(f'From AUC: Final Test AUC: {Final_Test_AUC_fromAUC:.4f}, Final Test AP: {Final_Test_AP_fromAUC:.4f}')
# Out:
# train:   0%|          | 0/1801 [00:00<?, ?it/s]
# tensor([[ 9.5319e-01,  0.0000e+00,  4.5833e-01,  4.7684e-07,  2.2426e-01,
#           0.0000e+00,  9.2770e-01,  0.0000e+00,  4.3417e-01,  0.0000e+00,
#           2.0689e-01,  0.0000e+00,  1.0009e+00,  9.8716e-01,  1.0477e+00,
#           0.0000e+00,  5.9283e-01,  0.0000e+00,  3.7430e-01,  0.0000e+00,
#           1.0206e+00,  0.0000e+00,  5.6531e-01,  0.0000e+00,  3.5240e-01,
#           0.0000e+00,  6.2639e-02,  0.0000e+00,  6.0648e-02,  0.0000e+00,
#           5.9055e-02,  0.0000e+00,  6.2155e-02,  0.0000e+00,  6.0207e-02,
#           0.0000e+00,  5.8652e-02,  0.0000e+00,  0.0000e+00,  8.1340e-01,
#           0.0000e+00,  4.8067e-01,  0.0000e+00,  3.2021e-01,  0.0000e+00,
#           7.8616e-01,  0.0000e+00,  4.5608e-01,  0.0000e+00,  3.0112e-01,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [-2.1423e-02,  1.0746e-01, -5.3406e-02,  1.0148e-01, -3.5812e-02,
#           8.0975e-02, -2.1851e-02,  1.0911e-01, -5.4138e-02,  1.0356e-01,
#          -3.6469e-02,  8.2764e-02,  9.7385e-01,  9.8199e-01,  4.7969e-01,
#           9.9703e-02,  2.2860e-01,  9.4278e-02,  1.3753e-01,  7.6619e-02,
#           4.8717e-01,  1.0053e-01,  2.3277e-01,  9.5569e-02,  1.4006e-01,
#           7.7876e-02,  3.6991e-01,  2.2528e-02,  1.7910e-01,  2.8811e-02,
#           1.0434e-01,  2.7705e-02,  3.7400e-01,  2.2249e-02,  1.8122e-01,
#           2.8664e-02,  1.0560e-01,  2.7688e-02,  1.2645e-01,  2.9007e-01,
#           1.2096e-01,  1.6596e-01,  9.5572e-02,  1.0885e-01,  1.2577e-01,
#           2.9636e-01,  1.2168e-01,  1.6943e-01,  9.6647e-02,  1.1102e-01,
#           2.2135e-01,  4.5162e-02,  1.3895e-01,  4.2990e-02,  9.0588e-02,
#           3.5940e-02,  2.2235e-01,  4.4559e-02,  1.4013e-01,  4.2603e-02,
#           9.1450e-02,  3.5750e-02],
#         [ 5.0383e-01,  0.0000e+00,  1.2692e-01,  0.0000e+00,  3.1967e-02,
#           0.0000e+00,  4.9479e-01,  0.0000e+00,  1.2242e-01,  0.0000e+00,
#           3.0281e-02,  0.0000e+00,  9.9690e-01,  9.8944e-01,  1.2486e+00,
#           0.0000e+00,  1.0593e+00,  0.0000e+00,  1.0117e+00,  0.0000e+00,
#           1.2555e+00,  0.0000e+00,  1.0713e+00,  0.0000e+00,  1.0257e+00,
#           0.0000e+00,  4.9644e-01,  0.0000e+00,  4.9644e-01,  0.0000e+00,
#           4.9644e-01,  0.0000e+00,  5.0664e-01,  0.0000e+00,  5.0664e-01,
#           0.0000e+00,  5.0664e-01,  0.0000e+00,  0.0000e+00,  1.1227e+00,
#           0.0000e+00,  1.0276e+00,  0.0000e+00,  1.0037e+00,  0.0000e+00,
#           1.1322e+00,  0.0000e+00,  1.0408e+00,  0.0000e+00,  1.0182e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [-4.8767e-02,  2.0083e-01, -1.3681e-01,  1.9160e-01, -1.1580e-01,
#           1.4759e-01, -4.4815e-02,  1.9891e-01, -1.3327e-01,  1.8927e-01,
#          -1.1311e-01,  1.4548e-01,  9.8389e-01,  9.9303e-01,  6.0635e-01,
#           1.3389e-01,  3.1105e-01,  1.4765e-01,  2.0667e-01,  1.3455e-01,
#           6.0890e-01,  1.3260e-01,  3.1192e-01,  1.4657e-01,  2.0671e-01,
#           1.3372e-01,  4.6763e-01,  0.0000e+00,  2.6203e-01,  2.1203e-02,
#           1.7551e-01,  3.3141e-02,  4.6580e-01,  0.0000e+00,  2.5990e-01,
#           2.1199e-02,  1.7368e-01,  3.3071e-02,  1.6913e-01,  3.6578e-01,
#           1.7533e-01,  2.2981e-01,  1.5410e-01,  1.7127e-01,  1.6624e-01,
#           3.6879e-01,  1.7336e-01,  2.3075e-01,  1.5286e-01,  1.7138e-01,
#           3.0242e-01,  0.0000e+00,  2.2209e-01,  2.1779e-02,  1.5961e-01,
#           3.5039e-02,  2.9944e-01,  0.0000e+00,  2.1964e-01,  2.1792e-02,
#           1.5765e-01,  3.5004e-02]], device='cuda:0', grad_fn=<CatBackward0>)
# test:val:   0%|          | 0/106 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 11
#       9 for epoch in range(0, 50):
#      10     loss_epoch = train(train_loader,epoch)
# ---> 11     val_auc, val_ap, val_loss = test(val_loader,data_type='val')
#      12     test_auc,test_ap,_ = test(test_loader,data_type='test')
#      13     if val_loss < Best_Val_fromloss:
#
# Cell In[13], line 28, in test(loader, data_type)
#      26 data = data.to(device)
#      27 out = model(data.x, data.edge_index, data.edge_mask, data.batch, data.z)
# ---> 28 loss = criterion(out.view(-1), data.label)
#      29 out = out.cpu().clone().detach()
#      30 scores = torch.cat((scores,out),dim = 0)
#
# File c:\ProgramData\Anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\ProgramData\Anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\loss.py:720, in BCEWithLogitsLoss.forward(self, input, target)
#     719 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 720     return F.binary_cross_entropy_with_logits(input, target,
#     721                                               self.weight,
#     722                                               pos_weight=self.pos_weight,
#     723                                               reduction=self.reduction)
#
# File c:\ProgramData\Anaconda3\envs\pytorch\lib\site-packages\torch\nn\functional.py:3160, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3157     reduction_enum = _Reduction.get_enum(reduction)
#    3159 if not (target.size() == input.size()):
# -> 3160     raise ValueError("Target size ({}) must be the same as input size ({})".format(target.size(), input.size()))
#    3162 return torch.binary_cross_entropy_with_logits(input, target, weight, pos_weight, reduction_enum)
#
# ValueError: Target size (torch.Size([4])) must be the same as input size (torch.Size([248]))

# %%
for i in test_loader:
    print(i)
    print(i.label)
    print(i.z)
    break
# Out:
# DataBatch(x=[9192, 32], edge_index=[2, 28008], z=[4], edge_mask=[28008], label=[4], batch=[9192], ptr=[5])
# tensor([1., 1., 1., 1.])
# tensor([0, 0, 0, 0])

# %%
test_df = pd.read_csv(data_path+'raw/test.csv')
test_feats = pd.read_csv(data_path+'raw/content.csv', delimiter='\t', header=None, index_col=0)
test_x = torch.tensor(test_feats.sort_index().values, dtype=torch.float)
test_id = test_df['id'].values
test_edge_index = torch.tensor(test_df[['from', 'to']].values.T)

# %%
r, c = test_edge_index
edge_mask = r.new_empty(r.size(0), dtype=torch.bool)

# %%
out = model(data_observed.x, test_edge_index, data.edge_mask, data.batch, data.z)
# Out:
# LinkPred()
